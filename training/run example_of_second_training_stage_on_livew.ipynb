# %%
run example_of_second_training_stage_on_livew
# Out:
# Split: 0
# Test Epoch:-1 [(0%)]	 Loss: 0.7826  Loss1: 0.3310  Loss2: 0.4516  Pearson:0.8772 Spearman:0.8513
# Test : Loss:0.8224
# Test ALL Pearson: 0.8733797722937439  ALL Pearson2: 0.755918670644005
# Test  ALL Spearman: 0.8469986349449414  ALL Spearman2: 0.7346136285411239
# Low Quality Pearson: 0.7521374394230086 Low Quality Pearson2: 0.6965419427785564
# Low Quality Spearman: 0.8315384615384616 Low Quality Spearman2: 0.7
# 0.001
# C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\nccl.py:16: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# Train Epoch:0 [(0%)]	 Loss: 0.4190 L1oss: 0.1761 Loss2: 0.2429  Pearson:0.9769 Spearman:0.9686
# Train ALL Pearson: 0.974711821637862  ALL Pearson2: 0.5891400819907905
# Train  ALL Spearman: 0.9691316117395243  ALL Spearman2: 0.6047089604250345
# Low Quality Pearson: 0.7530068722404725 Low Quality Pearson2: 0.6554868179966751
# ...

# %%
#calculate mean PLCC/SRCC
import numpy as np
plcc=[0.8698348123649732, 0.8442536019033617, 0.8800480901175668, 0.8877151358637513, 0.8571612780844585, 0.9036030303622625, 0.8726031887558666, 0.8430060583584755, 0.859772007950329, 0.8349921852903207]
srcc=[0.8479427004675842, 0.8092959547073328, 0.8311752351383437, 0.8600298439037167, 0.8246267171479482, 0.8784656125538238, 0.8489101803137052, 0.7943051682436215, 0.830636705698344, 0.807387876388287]
plcc_low=[0.8103162525470365, 0.6178131478449425, 0.644515912368581, 0.6555787992505708, 0.6299648280091208, 0.6968996364253595, 0.6520936381168772, 0.7519073046737177, 0.6051322827011023, 0.5636478026857176] 
srcc_low=[0.8792307692307693, 0.6324675324675325, 0.578544061302682, 0.6830870279146142, 0.7753246753246753, 0.751099706744868, 0.6233766233766234, 0.7639751552795032, 0.5955645161290324, 0.5313043478260869]
print('Mean PLCC:',np.mean(plcc),'Mean SRCC:',np.mean(srcc))
print('Mean PLCC of Low-quality Images:',np.mean(plcc_low),'Mean SRCC of Low-quality Images:',np.mean(srcc_low))
# Out:
# Mean PLCC: 0.8652989389051365 Mean SRCC: 0.8332775994562708
# Mean PLCC of Low-quality Images: 0.6627869604623025 Mean SRCC of Low-quality Images: 0.6813974415596387

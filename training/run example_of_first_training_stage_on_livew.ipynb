# %%
run example_of_first_training_stage_on_livew
# Out:
# Split: 0
# Test Epoch:-1 [(0%)]	 Loss: 23.8341  Loss1: 11.5731  Loss2: 12.2610  Pearson:0.1118 Spearman:0.1113
# Test : Loss:23.8528
# Test ALL Pearson: 0.18319287491771435  ALL Pearson2: 0.15949488137149645
# Test  ALL Spearman: 0.16681628419369268  ALL Spearman2: 0.13218943329329036
# Low Quality Pearson: 0.24249636668975413 Low Quality Pearson2: 0.14167818688382355
# Low Quality Spearman: 0.13999999999999999 Low Quality Spearman2: 0.1769230769230769
# 0.01
# C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\nccl.py:16: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# Train Epoch:0 [(0%)]	 Loss: 24.4525 L1oss: 11.7473 Loss2: 12.7052  Pearson:0.1281 Spearman:0.1191
# Train ALL Pearson: -0.003730729128849548  ALL Pearson2: 0.025245493702956784
# Train  ALL Spearman: 0.01381646667674277  ALL Spearman2: 0.028242419252849867
# Low Quality Pearson: -0.023178720012046614 Low Quality Pearson2: -0.027424040619784797
# ...
